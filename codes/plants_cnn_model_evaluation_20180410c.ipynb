# %% [markdown]
# # Plant Seedlings Classification
# ## CNN model evaluation
#
# Purpose of this notebook is to visualize some performance metric of CNN models estmated on the Plants data.
#
# Currently the accuracy on the validation set is provided.

# %%
# %matplotlib inline
from keras.models import load_model
import os
import sys
import pandas as pd
# Out:
# C:\programs_folder\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# %run helper_functions.py
# %run plants_functions.py
# %run plants_classes.py
# %run constants.py

# %%
# version id
ver_id = 'v20180416a'

# %%
# load model input data
try:
    fpath_input_data = os.path.join(MODEL_INPUT_DATA_FOLDER, 'model_input_data_%s.h5' % (ver_id))
    input_data = pickle_wrapper('r', fpath_input_data, x=None, rewrite=False)
except:
    sys.exit(str(fpath_input_data) + ' not found')
    
# load trained model  
try:
    fpath_model = os.path.join(TRAINED_MODELS_FOLDER, 'cnn_%s.h5' % (ver_id))
    model = load_model(fpath_model)
except:
    sys.exit(str(fpath_model) + ' not found')
    
# load csv history
try:
    fpath_csv_history = os.path.join(MODEL_HISTORY_FOLDER, 'cnn_hist_%s.csv' % (ver_id))
    csv_history = pd.read_csv(fpath_csv_history, sep=';')
except:
    sys.exit(str(fpath_history) + ' not found')
    
# load obj history
try:
    fpath_obj_history = os.path.join(MODEL_HISTORY_FOLDER, 'cnn_hist_%s.obj' % (ver_id))
    obj_history = pickle_wrapper('r', fpath_obj_history, x=None, rewrite=False)
except:
    sys.exit(str(fpath_history) + ' not found')

# %%
# unfold input data
X_train, X_test, Y_train, Y_test = input_data

# %%
csv_history.loc[:,('acc', 'val_acc')].plot()
